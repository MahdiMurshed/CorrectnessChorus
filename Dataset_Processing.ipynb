# %%
import pandas as pd
import os
import uuid

# %%
dataset1 = pd.read_csv("pdf.csv",index_col=0)
dataset1.head()
# Out:
#                                             Original  \
# 0  Condensation Robot-assisted laparoscopic techn...
# 1  Short titles Robot-assisted laparoscopic techn...
# 2  The advantages of RAL were evaluated through t...
# 3  Study design: Three electronic databases (PubM...
# 4  All retrospective studies documenting a compar...
#
#                                               Edited
# 0  Condensation Robot-assisted laparoscopic techn...
# 1  Short titles Robot-assisted laparoscopic techn...
# 2  The advantages of RAL were evaluated through t...
# 3  Study design: Three electronic databases (PubM...
# 4  All retrospective studies documenting a compar...

# %%
dataset1.rename(columns = {'Original':'input','Edited':'output'}, inplace = True)
#dataset1.drop(columns=['labels'],inplace=True)
#dataset1['input'] = 'grammar: ' + dataset1['input'].astype(str)
dataset1.head()
# Out:
#                                                input  \
# 0  Condensation Robot-assisted laparoscopic techn...
# 1  Short titles Robot-assisted laparoscopic techn...
# 2  The advantages of RAL were evaluated through t...
# 3  Study design: Three electronic databases (PubM...
# 4  All retrospective studies documenting a compar...
#
#                                               output
# 0  Condensation Robot-assisted laparoscopic techn...
# 1  Short titles Robot-assisted laparoscopic techn...
# 2  The advantages of RAL were evaluated through t...
# 3  Study design: Three electronic databases (PubM...
# 4  All retrospective studies documenting a compar...

# %%
#dataset1['input'] = 'grammar: ' + dataset1['input'].astype(str)
display(dataset1.drop_duplicates())
# Out:
#                                                   input  \
# 0     Condensation Robot-assisted laparoscopic techn...
# 1     Short titles Robot-assisted laparoscopic techn...
# 2     The advantages of RAL were evaluated through t...
# 3     Study design: Three electronic databases (PubM...
# 4     All retrospective studies documenting a compar...
# ...                                                 ...
# 1140  Future research should focus on the impact of ...
# 1141  The four substitutional incentive policies in ...
# 1142  However, some region has more suitable incenti...
# 1143  The impacts of these policies on EV adoption n...
# 1144                                                 33
#
#                                                  output
# 0     Condensation Robot-assisted laparoscopic techn...
# 1     Short titles Robot-assisted laparoscopic techn...
# 2     The advantages of RAL were evaluated through t...
# 3     Study design: Three electronic databases (PubM...
# ...

# %%
dt = dataset1.dropna()
dt.head()
# Out:
#                                                input  \
# 0  Condensation Robot-assisted laparoscopic techn...
# 1  Short titles Robot-assisted laparoscopic techn...
# 2  The advantages of RAL were evaluated through t...
# 3  Study design: Three electronic databases (PubM...
# 4  All retrospective studies documenting a compar...
#
#                                               output
# 0  Condensation Robot-assisted laparoscopic techn...
# 1  Short titles Robot-assisted laparoscopic techn...
# 2  The advantages of RAL were evaluated through t...
# 3  Study design: Three electronic databases (PubM...
# 4  All retrospective studies documenting a compar...

# %%
dt.drop_duplicates()
# Out:
#                                                   input  \
# 0     Condensation Robot-assisted laparoscopic techn...
# 1     Short titles Robot-assisted laparoscopic techn...
# 2     The advantages of RAL were evaluated through t...
# 3     Study design: Three electronic databases (PubM...
# 4     All retrospective studies documenting a compar...
# ...                                                 ...
# 1140  Future research should focus on the impact of ...
# 1141  The four substitutional incentive policies in ...
# 1142  However, some region has more suitable incenti...
# 1143  The impacts of these policies on EV adoption n...
# 1144                                                 33
#
#                                                  output
# 0     Condensation Robot-assisted laparoscopic techn...
# 1     Short titles Robot-assisted laparoscopic techn...
# 2     The advantages of RAL were evaluated through t...
# 3     Study design: Three electronic databases (PubM...
# ...

# %%
dt.shape
# Out:
# (29998, 0)

# %%
display(dt.head())
# Out:
# Empty DataFrame
# Columns: []
# Index: [I am reading score of Mahler is Symphony No . ., I am not interested in cars or electric appliances ., This is my homework for my English class ., In comparison , Canada is catches increased and decreased at steadier rate , although similarly to US ., Fortunately , my older sister is friend is a dentist .]

# %%
dt['input'] = 'grammar: ' + dt['input'].astype(str)
dt.to_csv("dataset2.csv")

# %%
dt['input'] = 'grammar: ' + dt['input'].astype(str)
dt.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'input'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
 
dataset2 = pd.read_csv("filename.csv",index_col=0)
dataset2.head()
# Out:
#       uid                                          sentence1  \
# 0       1  A person on a horse jumps over a broken down a...
# 1   10000                        A dog running in the grass.
# 2  100143          Two dogs play on the wooden floor inside.
# 3  100177  A woman in overalls is painting a landscape on...
# 4    1002  Small laughing child with blond-hair sitting a...
#
#                                        sentence2          label  \
# 0  A person is at a diner, ordering an omelette.  Contradiction
# 1        Outside there is an animal on the move.     Entailment
# 2                       the dogs have a toy ball        Neutral
# 3                      There is a women painting     Entailment
# 4                 A child is throwing a tantrum.  Contradiction
#
#                                                 tree
# 0  (9 (1 (14 (14 (41 a/a) (32 person/person)) (10...
# 1  (9 (4 (4 (35 /outside) (49 /there)) (49 /is)) ...
# ...

# %%
print("dataset1:")
display(dataset1.head())
print("dataset2:")
display(dataset2.head())
# Out:
# dataset1:
#                                                input  labels
# 0    I am reading score of Mahler is Symphony No . .       0
# 1  I am not interested in cars or electric applia...       1
# 2         This is my homework for my English class .       0
# 3  In comparison , Canada is catches increased an...       0
# 4  Fortunately , my older sister is friend is a d...       1
# dataset2:
#       uid                                          sentence1  \
# 0       1  A person on a horse jumps over a broken down a...
# 1   10000                        A dog running in the grass.
# 2  100143          Two dogs play on the wooden floor inside.
# 3  100177  A woman in overalls is painting a landscape on...
# 4    1002  Small laughing child with blond-hair sitting a...
#
#                                        sentence2          label  \
# 0  A person is at a diner, ordering an omelette.  Contradiction
# 1        Outside there is an animal on the move.     Entailment
# ...

# %%
display(dataset1.head())
dataset1.rename(columns = {'labels':'output',}, inplace = True)
#dataset1.drop(columns=['labels'],inplace=True)
display(dataset1.head())
# Out:
#                                                input  labels
# 0    I am reading score of Mahler is Symphony No . .       0
# 1  I am not interested in cars or electric applia...       1
# 2         This is my homework for my English class .       0
# 3  In comparison , Canada is catches increased an...       0
# 4  Fortunately , my older sister is friend is a d...       1
#                                                input  output
# 0    I am reading score of Mahler is Symphony No . .       0
# 1  I am not interested in cars or electric applia...       1
# 2         This is my homework for my English class .       0
# 3  In comparison , Canada is catches increased an...       0
# 4  Fortunately , my older sister is friend is a d...       1

# %%
display(dataset2.head())
dataset2.drop(columns=['label','tree','uid'], inplace=True)
display(dataset2.head())
# Out:
#       uid                                          sentence1  \
# 0       1  A person on a horse jumps over a broken down a...
# 1   10000                        A dog running in the grass.
# 2  100143          Two dogs play on the wooden floor inside.
# 3  100177  A woman in overalls is painting a landscape on...
# 4    1002  Small laughing child with blond-hair sitting a...
#
#                                        sentence2          label  \
# 0  A person is at a diner, ordering an omelette.  Contradiction
# 1        Outside there is an animal on the move.     Entailment
# 2                       the dogs have a toy ball        Neutral
# 3                      There is a women painting     Entailment
# 4                 A child is throwing a tantrum.  Contradiction
#
#                                                 tree
# 0  (9 (1 (14 (14 (41 a/a) (32 person/person)) (10...
# 1  (9 (4 (4 (35 /outside) (49 /there)) (49 /is)) ...
# ...

# %%
dataset2.rename(columns = {'sentence1':'input','sentence2':'output'}, inplace = True)
dataset2.head()
dataset2.tail()
# Out:
#                                                    input  \
# 16375              three people play soccer in the sand.
# 16376  A couple in old fashioned clothes sitting at a...
# 16377  A baby in a white and light purple outfit crying.
# 16378      A man shoots a gun that emits a bright light.
# 16379  Three little girls are sitting on a purple ben...
#
#                                 output
# 16375         A sport is being played.
# 16376  A couple is sitting at a table.
# 16377                A baby is crying.
# 16378              A man shoots a gun.
# 16379  Three children are being silly.

# %%
dataset2['input'] = 'grammar: ' + dataset2['input'].astype(str)
dataset2
# Out:
#                                                    input  \
# 0      grammar: grammar: A person on a horse jumps ov...
# 1          grammar: grammar: A dog running in the grass.
# 2      grammar: grammar: Two dogs play on the wooden ...
# 3      grammar: grammar: A woman in overalls is paint...
# 4      grammar: grammar: Small laughing child with bl...
# ...                                                  ...
# 16375  grammar: grammar: three people play soccer in ...
# 16376  grammar: grammar: A couple in old fashioned cl...
# 16377  grammar: grammar: A baby in a white and light ...
# 16378  grammar: grammar: A man shoots a gun that emit...
# 16379  grammar: grammar: Three little girls are sitti...
#
#                                               output
# 0      A person is at a diner, ordering an omelette.
# 1            Outside there is an animal on the move.
# 2                           the dogs have a toy ball
# 3                          There is a women painting
# ...

# %%
dataset2.to_csv("dataset1.csv")

# %%
dataset3 = pd.read_csv("pdf.csv",index_col=0)

# %%
dataset3.head()
# Out:
#                                             Original  \
# 0  Condensation Robot-assisted laparoscopic techn...
# 1  Short titles Robot-assisted laparoscopic techn...
# 2  The advantages of RAL were evaluated through t...
# 3  Study design: Three electronic databases (PubM...
# 4  All retrospective studies documenting a compar...
#
#                                               Edited
# 0  Condensation Robot-assisted laparoscopic techn...
# 1  Short titles Robot-assisted laparoscopic techn...
# 2  The advantages of RAL were evaluated through t...
# 3  Study design: Three electronic databases (PubM...
# 4  All retrospective studies documenting a compar...

# %%
dataset3.rename(columns = {'Edited':'output','Original':'input'}, inplace = True)
#dataset1.drop(columns=['labels'],inplace=True)
display(dataset3.head())
# Out:
#                                                input  \
# 0  Condensation Robot-assisted laparoscopic techn...
# 1  Short titles Robot-assisted laparoscopic techn...
# 2  The advantages of RAL were evaluated through t...
# 3  Study design: Three electronic databases (PubM...
# 4  All retrospective studies documenting a compar...
#
#                                               output
# 0  Condensation Robot-assisted laparoscopic techn...
# 1  Short titles Robot-assisted laparoscopic techn...
# 2  The advantages of RAL were evaluated through t...
# 3  Study design: Three electronic databases (PubM...
# 4  All retrospective studies documenting a compar...

# %%
display(dataset1.shape,dataset2.shape,dataset3.shape)
# Out:
# (29998, 2)
# (16380, 2)
# (1145, 2)

# %%
merged_dataset.tail()
# Out:
#                                                   input  \
# 1140  Future research should focus on the impact of ...
# 1141  The four substitutional incentive policies in ...
# 1142  However, some region has more suitable incenti...
# 1143  The impacts of these policies on EV adoption n...
# 1144                                                 33
#
#                                                  output
# 1140  Future research should focus on the impact of ...
# 1141  The four substitutional incentive policies in ...
# 1142  However, some region has more suitable incenti...
# 1143  The impacts of these policies on EV adoption n...
# 1144                                                 33

# %%
# importing pandas
import pandas as pd
  
# merging two csv files
df = pd.concat(
    map(pd.read_csv, ['filename.csv', 'pdf.csv']), ignore_index=True)
print(df)
# Out:
#        Unnamed: 0       uid  \
# 0               0       1.0
# 1               1   10000.0
# 2               2  100143.0
# 3               3  100177.0
# 4               4    1002.0
# ...           ...       ...
# 17520        1140       NaN
# 17521        1141       NaN
# 17522        1142       NaN
# 17523        1143       NaN
# 17524        1144       NaN
#
#                                                sentence1  \
# 0      A person on a horse jumps over a broken down a...
# 1                            A dog running in the grass.
# 2              Two dogs play on the wooden floor inside.
# 3      A woman in overalls is painting a landscape on...
# 4      Small laughing child with blond-hair sitting a...
# ...                                                  ...
# 17520                                                NaN
# 17521                                                NaN
# 17522                                                NaN
# ...

# %%
df = pd.read_csv("combined-csv-files.csv",index_col=0)
df.head()
# Out:
#       uid                                          sentence1  \
# 0       1  A person on a horse jumps over a broken down a...
# 1   10000                        A dog running in the grass.
# 2  100143          Two dogs play on the wooden floor inside.
# 3  100177  A woman in overalls is painting a landscape on...
# 4    1002  Small laughing child with blond-hair sitting a...
#
#                                        sentence2          label  \
# 0  A person is at a diner, ordering an omelette.  Contradiction
# 1        Outside there is an animal on the move.     Entailment
# 2                       the dogs have a toy ball        Neutral
# 3                      There is a women painting     Entailment
# 4                 A child is throwing a tantrum.  Contradiction
#
#                                                 tree
# 0  (9 (1 (14 (14 (41 a/a) (32 person/person)) (10...
# 1  (9 (4 (4 (35 /outside) (49 /there)) (49 /is)) ...
# ...

# %%
df.drop(columns=['label','tree','uid'],inplace=True)
df.rename(columns = {'sentence1':'input','sentence2':'target'}, inplace = True)
display(df.head())
# Out:
#                                                input  \
# 0  A person on a horse jumps over a broken down a...
# 1                        A dog running in the grass.
# 2          Two dogs play on the wooden floor inside.
# 3  A woman in overalls is painting a landscape on...
# 4  Small laughing child with blond-hair sitting a...
#
#                                           target
# 0  A person is at a diner, ordering an omelette.
# 1        Outside there is an animal on the move.
# 2                       the dogs have a toy ball
# 3                      There is a women painting
# 4                 A child is throwing a tantrum.

# %%
df['input'] = 'grammar: ' + df['input'].astype(str)
#df['input'].map('grammer{}'.format)
display(df.head())
# Out:
#                                                input  \
# 0  grammar: A person on a horse jumps over a brok...
# 1               grammar: A dog running in the grass.
# 2  grammar: Two dogs play on the wooden floor ins...
# 3  grammar: A woman in overalls is painting a lan...
# 4  grammar: Small laughing child with blond-hair ...
#
#                                           target
# 0  A person is at a diner, ordering an omelette.
# 1        Outside there is an animal on the move.
# 2                       the dogs have a toy ball
# 3                      There is a women painting
# 4                 A child is throwing a tantrum.

# %%
df.to_csv('final3.csv')

# %%
dataset3 = pd.read_csv("pdf.csv",index_col=0)

# %%
dataset3.rename(columns = {'Edited':'tar','Original':'input'}, inplace = True)
#dataset1.drop(columns=['labels'],inplace=True)
display(dataset3.head())
# Out:
#                                                input  \
# 0  Condensation Robot-assisted laparoscopic techn...
# 1  Short titles Robot-assisted laparoscopic techn...
# 2  The advantages of RAL were evaluated through t...
# 3  Study design: Three electronic databases (PubM...
# 4  All retrospective studies documenting a compar...
#
#                                               output
# 0  Condensation Robot-assisted laparoscopic techn...
# 1  Short titles Robot-assisted laparoscopic techn...
# 2  The advantages of RAL were evaluated through t...
# 3  Study design: Three electronic databases (PubM...
# 4  All retrospective studies documenting a compar...

# %%
dataset3['input'] = 'grammar: ' + dataset3['input'].astype(str)
#df['input'].map('grammer{}'.format)
display(dataset3.head())
# Out:
#                                                input  \
# 0  grammar: Condensation Robot-assisted laparosco...
# 1  grammar: Short titles Robot-assisted laparosco...
# 2  grammar: The advantages of RAL were evaluated ...
# 3  grammar: Study design: Three electronic databa...
# 4  grammar: All retrospective studies documenting...
#
#                                               output
# 0  Condensation Robot-assisted laparoscopic techn...
# 1  Short titles Robot-assisted laparoscopic techn...
# 2  The advantages of RAL were evaluated through t...
# 3  Study design: Three electronic databases (PubM...
# 4  All retrospective studies documenting a compar...

# %%
dataset3.to_csv('final_1.csv')

# %%
dt= pd.read_csv("train.csv",index_col=0)
dt.head(10)
# Out:
#                                                                                                target
# input
# grammar: So I think we can not live if old peop...  So I think we would not be alive if our ancest...
# grammar: So I think we can not live if old peop...  So I think we could not live if older people d...
# grammar: So I think we can not live if old peop...  So I think we can not live if old people could...
# grammar: So I think we can not live if old peop...  So I think we can not live if old people can n...
# grammar: For not use car .                                                  Not for use with a car .
# grammar: For not use car .                                                   Do not use in the car .
# grammar: For not use car .                                                         Car not for use .
# grammar: For not use car .                                                     Can not use the car .
# ...

# %%
dt.dropna(axis=1, inplace = True)
dt.head()
# Out:
#                                                                                                target
# input
# grammar: So I think we can not live if old peop...  So I think we would not be alive if our ancest...
# grammar: So I think we can not live if old peop...  So I think we could not live if older people d...
# grammar: So I think we can not live if old peop...  So I think we can not live if old people could...
# grammar: So I think we can not live if old peop...  So I think we can not live if old people can n...
# grammar: For not use car .                                                  Not for use with a car .

# %%
dt.shape
# Out:
# (3016, 1)

# %%
dt.isnull().any()
# Out:
# target    False
# dtype: bool

# %%
df.to_csv('train1.csv')

# %%
pip install faker
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 19.7 MB/s eta 0:00:00
# ...

# %%
from faker import Faker
import pandas as pd
import numpy as np

# %%
fake = Faker()

# %%
for _ in range(100):
  x = fake.text()
  print(x ,"\n")
# Out:
# Mouth listen simple too letter rich. Sit upon own dog.
#
# Coach rock people food mind fire. Rock also economic contain international all.
# Machine raise career. Third hard bill operation animal.
#
# Effort enter may news step take history. Member learn side I order president able.
# Method understand with. Why speech investment bring piece course white bag.
#
# Measure where stock security series prevent spring. The about bank future person indicate. Time personal candidate our.
# Happen nor bad. Feel so half situation even.
#
# Sense not take first. Set choice nothing chair still position scientist number. List big ask his life blue quite area.
# Anyone laugh cut debate land. Success create this thousand push past us.
#
# Out all interesting live this. Soon what provide quickly less ready receive.
# General technology shoulder top. News various window company avoid result huge. Also many state should election appear.
#
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv("final_1.csv",index_col=0)
df.head()
# Out:
#                                                                                                output
# input
# grammar: Condensation Robot-assisted laparoscop...  Condensation Robot-assisted laparoscopic techn...
# grammar: Short titles Robot-assisted laparoscop...  Short titles Robot-assisted laparoscopic techn...
# grammar: The advantages of RAL were evaluated t...  The advantages of RAL were evaluated through t...
# grammar: Study design: Three electronic databas...  Study design: Three electronic databases (PubM...
# grammar: All retrospective studies documenting ...  All retrospective studies documenting a compar...

# %%
df.dropna(axis=1, inplace = True)
df.head()
# Out:
#                                                                                                output
# input
# grammar: Condensation Robot-assisted laparoscop...  Condensation Robot-assisted laparoscopic techn...
# grammar: Short titles Robot-assisted laparoscop...  Short titles Robot-assisted laparoscopic techn...
# grammar: The advantages of RAL were evaluated t...  The advantages of RAL were evaluated through t...
# grammar: Study design: Three electronic databas...  Study design: Three electronic databases (PubM...
# grammar: All retrospective studies documenting ...  All retrospective studies documenting a compar...

# %%
df.to_csv("final.csv")

# %%
df = pd.read_csv("final_1.csv",index_col=0)
df.head()

# %%
class FileSettings(object):
    def __init__(self, file_name, row_size=100):
        self.file_name = file_name
        self.row_size = row_size

class FileSplitter(object):

    def __init__(self, file_settings):
        self.file_settings = file_settings

        if type(self.file_settings).__name__ != "FileSettings":
            raise Exception("Please pass correct instance ")

        self.df = pd.read_csv(self.file_settings.file_name,
                              chunksize=self.file_settings.row_size)

    def run(self, directory="temp"):

        try:os.makedirs(directory)
        except Exception as e:pass

        counter = 0

        while True:
            try:
                file_name = "{}/{}_{}_row_{}_{}.csv".format(
                    directory,  self.file_settings.file_name.split(".")[0], counter, self.file_settings.row_size, uuid.uuid4().__str__()
                )
                df = next(self.df).to_csv(file_name)
                counter = counter + 1
            except StopIteration:
                break
            except Exception as e:
                print("Error:",e)
                break

        return True


def main():
    helper =  FileSplitter(FileSettings(
        file_name='combined-csv-files.csv',
        row_size=10
    ))
    helper.run()

main()

# %%
 import pandas as pd
 dt = pd.read_csv("final4.csv",index_col=0)
 dt.head()
# Out:
#                                                                                            target
# input
# grammar: A person on a horse jumps over a broke...  A person is at a diner, ordering an omelette.
# grammar: A dog running in the grass.                      Outside there is an animal on the move.
# grammar: Two dogs play on the wooden floor inside.                       the dogs have a toy ball
# grammar: A woman in overalls is painting a land...                      There is a women painting
# grammar: Small laughing child with blond-hair s...                 A child is throwing a tantrum.

# %%
dt.shape
# Out:
# (17527, 1)

# %%
display(dt)
# Out:
#                                                                                            target
# input
# grammar: A person on a horse jumps over a broke...  A person is at a diner, ordering an omelette.
# grammar: A dog running in the grass.                      Outside there is an animal on the move.
# grammar: Two dogs play on the wooden floor inside.                       the dogs have a toy ball
# grammar: A woman in overalls is painting a land...                      There is a women painting
# grammar: Small laughing child with blond-hair s...                 A child is throwing a tantrum.
# ...                                                                                           ...
# grammar: The four substitutional incentive poli...                                            NaN
# grammar: However, some region has more suitable...                                            NaN
# ...

# %%
dt.isnull().any()
# Out:
# target    True
# dtype: bool

# %%
dt1 = dt.dropna()
print(dt1)
# Out:
#                                                                                            target
# input
# grammar: A person on a horse jumps over a broke...  A person is at a diner, ordering an omelette.
# grammar: A dog running in the grass.                      Outside there is an animal on the move.
# grammar: Two dogs play on the wooden floor inside.                       the dogs have a toy ball
# grammar: A woman in overalls is painting a land...                      There is a women painting
# grammar: Small laughing child with blond-hair s...                 A child is throwing a tantrum.
# ...                                                                                           ...
# grammar: three people play soccer in the sand.                           A sport is being played.
# grammar: A couple in old fashioned clothes sitt...                A couple is sitting at a table.
# ...

# %%
dt1.shape
# Out:
# (16380, 1)

# %%
df = pd.DataFrame(dt1)
  
display(df.drop_duplicates())
# Out:
#                                                                                            target
# input
# grammar: A person on a horse jumps over a broke...  A person is at a diner, ordering an omelette.
# grammar: A dog running in the grass.                      Outside there is an animal on the move.
# grammar: Two dogs play on the wooden floor inside.                       the dogs have a toy ball
# grammar: A woman in overalls is painting a land...                      There is a women painting
# grammar: Small laughing child with blond-hair s...                 A child is throwing a tantrum.
# ...                                                                                           ...
# grammar: A baby wearing a purple outfit and lay...   A grown man laughs while laying on a blanket
# grammar: three people play soccer in the sand.                           A sport is being played.
# ...

# %%
df.shape
# Out:
# (16380, 1)

# %%
df.to_csv("paraphrasing2.csv")

# %%
dataset1 = pd.read_csv("train_final.csv",index_col=0)
dataset2 = pd.read_csv("eval.csv",index_col=0)

# %%
dataset1.head()
# Out:
#                                                                                                target
# input
# grammar: So I think we can not live if old peop...  So I think we would not be alive if our ancest...
# grammar: So I think we can not live if old peop...  So I think we could not live if older people d...
# grammar: So I think we can not live if old peop...  So I think we can not live if old people could...
# grammar: So I think we can not live if old peop...  So I think we can not live if old people can n...
# grammar: For not use car .                                                  Not for use with a car .

# %%
dataset2.head()
# Out:
#                                                                                                target
# input
# grammar: New and new technology has been introd...    New technology has been introduced to society .
# grammar: New and new technology has been introd...  New technology has been introduced into the so...
# grammar: New and new technology has been introd...  Newer and newer technology has been introduced...
# grammar: New and new technology has been introd...  Newer and newer technology has been introduced...
# grammar: One possible outcome is that an enviro...  One possible outcome is that an environmentall...

# %%
merged_dataset = pd.concat([ dataset1, dataset2])
merged_dataset.shape
# Out:
# (6004, 1)

# %%
merged_dataset.to_csv("JFLAG.csv")
